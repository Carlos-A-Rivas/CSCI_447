# %%
import random
import numpy as np
import os

print("testing...")
# Out:
# testing...

# %%
# Consider discretizing the labels so the arrays can be numpy
# DATASET.PARTITIONS FORMAT: dataset.partitions[fold][example][attribute]
'''
self.line_count - total # of examples
self.partition_count - total # of partitions
self.example_count - total # of examples
self.attribute_count - total # of attributes for each example
'''

class dataset:
    def __init__(self, data_path, label_location, processed_flag):
        if (processed_flag == False):
            # Separating the .data file into lines, and shuffling the lines
            with open(data_path, 'r') as file:
                lines = file.readlines()
            random.shuffle(lines)
            self.data_lines = lines
            #print(f"Data Lines Array Unprocessed: {self.data_lines}")
    
            # Deliminate strings into lists
            for i in range(len(self.data_lines)):
                self.data_lines[i] = self.data_lines[i].strip()
                self.data_lines[i] = self.data_lines[i].split(',')
    
            # If the labels are in the first location, move them to the last location in the line
            #print(f"Data Lines Array Deliminated: {self.data_lines}")
            if (label_location == 'first'):
                for i in range(len(self.data_lines)):
                    first_item = self.data_lines[i].pop(0)
                    self.data_lines[i].append(first_item)
                #print(f"Data Lines Array W/ Indices Swapped: {self.data_lines}")
    
            # Folding the data...
            self.line_count = len(self.data_lines)
            partition_size = self.line_count//10
            partition_remainder = self.line_count%10
            self.partitions = [self.data_lines[i * partition_size:(i + 1) * partition_size] for i in range(10)] # Separating the lines list into 10 lists of lines
            if (partition_remainder != 0):
                for i in range(partition_remainder):
                    # MIGHT NEED TO ADD EXTRA INDICE DIMENSION WHEN DATA IS DELIMINATED PRIOR
                    self.partitions[:][i].append(self.data_lines[-(i+1)])
            
            # General dataset information setters
            self.partition_count = 10
            self.example_count = self.line_count
            self.attribute_count = len(self.partitions[0][0])
        else:
            #extract processed data
            self.partitions = []
            with open(data_path, 'r') as file:  #open csv file of processed data
                for line in file:
                    line = line.strip() #strip each line of any white space or newlines
                    examples = line.split(";") #Split each line into examples by each semicolon
                    attributes = [list(map(str, item.split(","))) for item in examples] #seperate each attribute and remove commas
                    self.partitions.append(attributes) # put into 3d array
               
                
        
    def save(self, save_file_name, save_folder):
        # Saves the data based on our convention: Each line is a partition, semicolons separate examples, commas separate attributes/labels
        folder_path = os.path.expanduser(f"{save_folder}/processed_data")  
        os.makedirs(folder_path, exist_ok=True)
        #get/create the path to the folder that the file should be saved to
        file_path = os.path.join(folder_path, save_file_name)
        #create the file path
        with open(f"{file_path}.csv", "w") as file:
            #open a csv file in the desired location
            for line in self.partitions:
                partition_lines = ";".join([",".join(map(str, sub_array)) for sub_array in line])
                #for each partition, join each example by a semi colon and each attribute by a comma
                file.write(partition_lines + "\n")
                #write each partition into the file with each 
        print(f"CSV file saved to {file_path}")
        return


    def imputate(self, voter_bool):
        # Replaces question marks in a dataset with a random value between the min/max of an attribute value
        # Breast cancer has a range of 1-10 for the attribute that is missing values
        # voter_bool indicates whether you are working with the voter dataset, where attributes are strings of 'y' or 'n' instead of numbers
        voter_options = ['y', 'n']
        
        for partition in range(self.partition_count):
            for example in range(self.example_count):
                for attribute in range(self.attribute_count):
                    # if this statement is entered that means there is a missing piece of attribute data, so imputation needs to occur at this location
                    if (self.partitions[partition][example][attribute] == '?'):
                        # This will be the imputation method using 'y' or 'n'
                        if (voter_bool == True):
                            self.partitions[partition][example][attribute] = random.choice(voter_options)
                        # This will be the imputation method using range 1-10
                        else:
                            self.partitions[partition][example][attribute] = random.randint(1,10)



    def discretize(self, attribute_indice, divisions):
        # Takes a continous attribute and "bins" the attribute into discrete groups. May need to create a dictionary
        return

    def add_noise(self):
        return

# %%
# Constructor Testing

print(f"Folded Array: {iris_dataset.partitions}")
print(f"Data first layer length (Should be length 10): {len(iris_dataset.partitions)}")
#print(f"Data second layer length (Should be {iris_dataset.line_count}): {len(iris_dataset.partitions[1])}")
#print(f"Data third layer length (Should be # of items in a line): {len(iris_dataset.partitions[0][0])}")

total_line_count = 0
for i, partition in enumerate(iris_dataset.partitions):
    print(f'Fold {i+1} Length: {len(partition)}')
    total_line_count += len(partition)
print(f"Number of Examples: {total_line_count}")

#print(iris_dataset.partitions[0][0][2])
print(iris_dataset.attribute_count)
# Out:
# Folded Array: [[['4.9', '3.1', '1.5', '0.1', 'Iris-setosa\n'], ['6.5', '3.0', '5.8', '2.2', 'Iris-virginica\n'], ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica\n'], ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa\n'], ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa\n'], ['5.7', '2.9', '4.2', '1.3', 'Iris-versicolor\n'], ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica\n'], ['6.1', '3.0', '4.6', '1.4', 'Iris-versicolor\n'], ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa\n'], ['7.3', '2.9', '6.3', '1.8', 'Iris-virginica\n'], ['5.4', '3.0', '4.5', '1.5', 'Iris-versicolor\n'], ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor\n'], ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa\n'], ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica\n'], ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica\n'], ['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor\n']], [['5.1', '3.7', '1.5', '0.4', 'Iris-setosa\n'], ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa\n'], ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa\n'], ['5.0', '2.0', '3.5', '1.0', 'Iris-versicolor\n'], ['5.2', '3.4', '1.4', '0.2', 'Iris-setosa\n'], ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor\n'], ['6.9', '3.2', '5.7', '2.3', 'Iris-virginica\n'], ['6.7', '3.3', '5.7', '2.5', 'Iris-virginica\n'], ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor\n'], ['6.1', '3.0', '4.9', '1.8', 'Iris-virginica\n'], ['6.7', '3.1', '4.4', '1.4', 'Iris-versicolor\n'], ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa\n'], ['4.6', '3.6', '1.0', '0.2', 'Iris-setosa\n'], ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor\n'], ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa\n']], [['7.6', '3.0', '6.6', '2.1', 'Iris-virginica\n'], ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa\n'], ['7.7', '3.0', '6.1', '2.3', 'Iris-virginica\n'], ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica\n'], ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa\n'], ['6.0', '2.9', '4.5', '1.5', 'Iris-versicolor\n'], ['6.7', '3.1', '5.6', '2.4', 'Iris-virginica\n'], ['6.9', '3.1', '5.4', '2.1', 'Iris-virginica\n'], ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa\n'], ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor\n'], ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa\n'], ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa\n'], ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor\n'], ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa\n'], ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor\n']], [['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor\n'], ['5.8', '2.7', '3.9', '1.2', 'Iris-versicolor\n'], ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica\n'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa\n'], ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor\n'], ['6.4', '3.2', '5.3', '2.3', 'Iris-virginica\n'], ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor\n'], ['6.3', '2.8', '5.1', '1.5', 'Iris-virginica\n'], ['6.4', '2.8', '5.6', '2.1', 'Iris-virginica\n'], ['5.9', '3.0', '4.2', '1.5', 'Iris-versicolor\n'], ['6.3', '2.5', '4.9', '1.5', 'Iris-versicolor\n'], ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor\n'], ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica\n'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa\n'], ['\n']], [['6.0', '2.2', '5.0', '1.5', 'Iris-virginica\n'], ['7.7', '3.8', '6.7', '2.2', 'Iris-virginica\n'], ['6.3', '3.3', '6.0', '2.5', 'Iris-virginica\n'], ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica\n'], ['6.6', '3.0', '4.4', '1.4', 'Iris-versicolor\n'], ['6.1', '2.9', '4.7', '1.4', 'Iris-versicolor\n'], ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor\n'], ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor\n'], ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor\n'], ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa\n'], ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica\n'], ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa\n'], ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor\n'], ['6.0', '2.2', '4.0', '1.0', 'Iris-versicolor\n'], ['5.7', '2.8', '4.1', '1.3', 'Iris-versicolor\n']], [['6.7', '3.0', '5.2', '2.3', 'Iris-virginica\n'], ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor\n'], ['5.1', '3.3', '1.7', '0.5', 'Iris-setosa\n'], ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor\n'], ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor\n'], ['6 ...
# Data first layer length (Should be length 10): 10
# Fold 1 Length: 16
# Fold 2 Length: 15
# Fold 3 Length: 15
# Fold 4 Length: 15
# Fold 5 Length: 15
# Fold 6 Length: 15
# Fold 7 Length: 15
# Fold 8 Length: 15
# Fold 9 Length: 15
# Fold 10 Length: 15
# Number of Examples: 151
# 5

# %%
# .save() testing
iris_dataset = dataset("C:/Users/david/OneDrive/Desktop/CSCI_447/Datasets/iris.data", 'last', False)
save_test = "save_test"
iris_dataset.save(save_test)
# Out:
# C:\Users\david\processed_data\save_test
# [[['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['6.5', '3.0', '5.2', '2.0', 'Iris-virginica'], ['5.7', '2.5', '5.0', '2.0', 'Iris-virginica'], ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa'], ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor'], ['5.6', '3.0', '4.1', '1.3', 'Iris-versicolor'], ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa'], ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica'], ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa'], ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa'], ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor'], ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor'], ['7.7', '2.8', '6.7', '2.0', 'Iris-virginica'], ['7.2', '3.0', '5.8', '1.6', 'Iris-virginica'], ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'], ['']], [['4.9', '2.5', '4.5', '1.7', 'Iris-virginica'], ['5.7', '3.0', '4.2', '1.2', 'Iris-versicolor'], ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa'], ['6.7', '3.0', '5.2', '2.3', 'Iris-virginica'], ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor'], ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor'], ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa'], ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica'], ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa'], ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa'], ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor'], ['5.1', '2.5', '3.0', '1.1', 'Iris-versicolor'], ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']], [['5.1', '3.8', '1.5', '0.3', 'Iris-setosa'], ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor'], ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica'], ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'], ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor'], ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor'], ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa'], ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica'], ['6.2', '2.9', '4.3', '1.3', 'Iris-versicolor'], ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa'], ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa'], ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa'], ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica'], ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa'], ['6.3', '2.9', '5.6', '1.8', 'Iris-virginica']], [['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor'], ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa'], ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa'], ['5.5', '2.5', '4.0', '1.3', 'Iris-versicolor'], ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa'], ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor'], ['6.3', '2.5', '5.0', '1.9', 'Iris-virginica'], ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa'], ['6.3', '2.7', '4.9', '1.8', 'Iris-virginica'], ['7.4', '2.8', '6.1', '1.9', 'Iris-virginica'], ['6.3', '2.3', '4.4', '1.3', 'Iris-versicolor'], ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa'], ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor'], ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa'], ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']], [['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor'], ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica'], ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa'], ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa'], ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa'], ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor'], ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor'], ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa'], ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor'], ['7.6', '3.0', '6.6', '2.1', 'Iris-virginica'], ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa'], ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica'], ['6.7', '3.3', '5.7', '2.1', 'Iris-virginica'], ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor'], ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']], [['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'], ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa'], ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa'], ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa'], ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica'], ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor'], ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor'], ['6.2', '3.4', '5.4', '2.3', 'Iris-virginica'], ['6.8', '3.0', '5.5', '2.1', 'Iris-virginica'], ['5.6', '2.5', '3.9 ...
# CSV file saved to C:\Users\david\processed_data\save_test

# %%
# .extract() testing
iris_dataset = dataset(r"C:\Users\david\processed_data\save_test.csv", 'last', True)
# Out:
# [[['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['6.5', '3.0', '5.2', '2.0', 'Iris-virginica'], ['5.7', '2.5', '5.0', '2.0', 'Iris-virginica'], ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa'], ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor'], ['5.6', '3.0', '4.1', '1.3', 'Iris-versicolor'], ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa'], ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica'], ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa'], ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa'], ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor'], ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor'], ['7.7', '2.8', '6.7', '2.0', 'Iris-virginica'], ['7.2', '3.0', '5.8', '1.6', 'Iris-virginica'], ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'], ['']], [['4.9', '2.5', '4.5', '1.7', 'Iris-virginica'], ['5.7', '3.0', '4.2', '1.2', 'Iris-versicolor'], ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa'], ['6.7', '3.0', '5.2', '2.3', 'Iris-virginica'], ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor'], ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor'], ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa'], ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica'], ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa'], ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa'], ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor'], ['5.1', '2.5', '3.0', '1.1', 'Iris-versicolor'], ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']], [['5.1', '3.8', '1.5', '0.3', 'Iris-setosa'], ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor'], ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica'], ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica'], ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor'], ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor'], ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa'], ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica'], ['6.2', '2.9', '4.3', '1.3', 'Iris-versicolor'], ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa'], ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa'], ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa'], ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica'], ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa'], ['6.3', '2.9', '5.6', '1.8', 'Iris-virginica']], [['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor'], ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa'], ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa'], ['5.5', '2.5', '4.0', '1.3', 'Iris-versicolor'], ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa'], ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor'], ['6.3', '2.5', '5.0', '1.9', 'Iris-virginica'], ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa'], ['6.3', '2.7', '4.9', '1.8', 'Iris-virginica'], ['7.4', '2.8', '6.1', '1.9', 'Iris-virginica'], ['6.3', '2.3', '4.4', '1.3', 'Iris-versicolor'], ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa'], ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor'], ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa'], ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']], [['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor'], ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica'], ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa'], ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa'], ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa'], ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor'], ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor'], ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa'], ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor'], ['7.6', '3.0', '6.6', '2.1', 'Iris-virginica'], ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa'], ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica'], ['6.7', '3.3', '5.7', '2.1', 'Iris-virginica'], ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor'], ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']], [['5.8', '2.7', '5.1', '1.9', 'Iris-virginica'], ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa'], ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa'], ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa'], ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica'], ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor'], ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor'], ['6.2', '3.4', '5.4', '2.3', 'Iris-virginica'], ['6.8', '3.0', '5.5', '2.1', 'Iris-virginica'], ['5.6', '2.5', '3.9 ...

# %%
# .imputate() testing
cancer_dataset = dataset('/home/carlos/Machine_Learning_Practice/datasets/breast-cancer-wisconsin.data', 'last')
print(f"Cancer Dataset w/o imputation: {cancer_dataset.partitions}")
votes_dataset = dataset('/home/carlos/Machine_Learning_Practice/datasets/house-votes-84.data', 'first')
print(f"voter Dataset w/o imputation: {votes_dataset.partitions}")


cancer_dataset.imputate(False)
print(f"Cancer Dataset w/ imputation: {cancer_dataset.partitions}")
votes_dataset.imputate(True)
print(f"voter Dataset w/o imputation: {votes_dataset.partitions}")
# Out:
# Cancer Dataset w/o imputation: [[['1216694', '10', '8', '8', '4', '10', '10', '8', '1', '1', '4\n'], ['1113061', '5', '1', '1', '1', '2', '1', '3', '1', '1', '2\n'], ['1333877', '5', '4', '5', '1', '8', '1', '3', '6', '1', '2\n'], ['1299924', '5', '1', '1', '1', '2', '1', '2', '1', '1', '2\n'], ['798429', '1', '1', '1', '1', '2', '1', '3', '1', '1', '2\n'], ['1218982', '4', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1183516', '3', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1213784', '3', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1348851', '3', '1', '1', '1', '2', '1', '3', '1', '1', '2\n'], ['1033078', '2', '1', '1', '1', '2', '1', '1', '1', '5', '2\n'], ['1219859', '8', '10', '8', '8', '4', '8', '7', '7', '1', '4\n'], ['1218860', '1', '1', '1', '1', '1', '1', '3', '1', '1', '2\n'], ['1176187', '3', '1', '1', '1', '2', '1', '3', '1', '1', '2\n'], ['1295529', '2', '5', '7', '6', '4', '10', '7', '6', '1', '4\n'], ['1253955', '8', '7', '4', '4', '5', '3', '5', '10', '1', '4\n'], ['474162', '8', '7', '8', '5', '5', '10', '9', '10', '1', '4\n'], ['1070522', '3', '1', '1', '1', '1', '1', '2', '1', '1', '2\n'], ['635844', '8', '4', '10', '5', '4', '4', '7', '10', '1', '4\n'], ['769612', '4', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['695091', '1', '1', '1', '1', '2', '1', '2', '1', '1', '2\n'], ['1116116', '9', '10', '10', '1', '10', '8', '3', '3', '1', '4\n'], ['1294413', '1', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1343374', '10', '10', '8', '10', '6', '5', '10', '3', '1', '4\n'], ['1183596', '3', '1', '3', '1', '3', '4', '1', '1', '1', '2\n'], ['805448', '1', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1113483', '5', '2', '3', '1', '6', '10', '5', '1', '1', '4\n'], ['769612', '3', '1', '1', '2', '2', '1', '1', '1', '1', '2\n'], ['1239232', '3', '3', '2', '6', '3', '3', '3', '5', '1', '2\n'], ['1173216', '10', '10', '10', '3', '10', '8', '8', '1', '1', '4\n'], ['145447', '8', '4', '4', '1', '2', '9', '3', '3', '1', '4\n'], ['1330361', '5', '1', '1', '1', '2', '1', '2', '1', '1', '2\n'], ['640712', '1', '1', '1', '1', '2', '1', '2', '1', '1', '2\n'], ['1174057', '4', '2', '1', '1', '2', '2', '3', '1', '1', '2\n'], ['1298484', '10', '3', '4', '5', '3', '10', '4', '1', '1', '4\n'], ['1202253', '5', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1218741', '10', '10', '9', '3', '7', '5', '3', '5', '1', '4\n'], ['1298360', '1', '1', '1', '1', '2', '1', '1', '1', '1', '2\n'], ['1155546', '2', '1', '1', '2', '3', '1', '2', '1', '1', '2\n'], ['1054593', '10', '5', '5', '3', '6', '7', '7', '10', '1', '4\n'], ['1173235', '3', '3', '2', '1', '2', '3', '3', '1', '1', '2\n'], ['1276091', '6', '1', '1', '3', '2', '1', '1', '1', '1', '2\n'], ['1170420', '1', '6', '8', '10', '8', '10', '5', '7', '1', '4\n'], ['1196915', '10', '7', '7', '4', '5', '10', '5', '7', '2', '4\n'], ['659642', '10', '8', '4', '4', '4', '10', '3', '10', '4', '4\n'], ['1311108', '1', '1', '1', '3', '2', '1', '1', '1', '1', '2\n'], ['1237674', '3', '1', '2', '1', '2', '1', '2', '1', '1', '2\n'], ['1174057', '1', '1', '2', '2', '2', '1', '3', '1', '1', '2\n'], ['1110503', '5', '5', '5', '8', '10', '8', '7', '3', '7', '4\n'], ['353098', '4', '1', '1', '2', '2', '1', '1', '1', '1', '2\n'], ['1184241', '2', '1', '1', '1', '2', '1', '2', '1', '1', '2\n'], ['1126417', '10', '6', '4', '1', '3', '4', '3', '2', '3', '4\n'], ['1015425', '3', '1', '1', '1', '2', '2', '3', '1', '1', '2\n'], ['897471', '4', '8', '8', '5', '4', '5', '10', '4', '1', '4\n'], ['1202812', '5', '3', '3', '3', '6', '10', '3', '1', '1', '4\n'], ['1112209', '8', '10', '10', '1', '3', '6', '3', '9', '1', '4\n'], ['1049815', '4', '1', '1', '1', '2', '1', '3', '1', '1', '2\n'], ['850831', '2', '7', '10', '10', '7', '10', '4', '9', '4', '4\n'], ['1205579', '8', '7', '6', '4', '4', '10', '5', '1', '1', '4\n'], ['1253917', '4', '1', '1', '2', '2', '1', '2', '1', '1', '2\n'], ['432809', '3', '1', '3', '1', '2', '?', '2', '1', '1', '2\n'], ['1229929', '1', '1', '1', '1', '2', ...
# voter Dataset w/o imputation: [[['y', 'n', 'n', 'n', 'y', 'y', '?', 'n', '?', 'n', 'n', 'n', 'n', 'y', '?', 'n\n', 'democrat'], ['y', 'y', 'n', 'n', 'y', '?', 'n', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'n', 'y\n', 'democrat'], ['?', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'y\n', 'democrat'], ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n\n', 'republican'], ['n', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y\n', 'republican'], ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'y', '?', '?', '?', 'y', 'n', 'y\n', 'republican'], ['n', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'n', 'y', 'n', 'y', 'y', 'y', '?', 'y\n', 'republican'], ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'n', 'y', 'n', 'y\n', 'republican'], ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n', 'n', 'y', '?\n', 'democrat'], ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'n', 'y', 'y', 'n', 'y\n', 'republican'], ['n', '?', 'y', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n', 'n', 'n', 'y', '?\n', 'democrat'], ['y', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'n', 'y', 'n', 'y\n', 'democrat'], ['y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'n', 'y', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['y', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', '?', 'y', 'y', 'n', 'n\n', 'republican'], ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'y\n', 'republican'], ['y', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'n', 'y\n', 'democrat'], ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n\n', 'republican'], ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', '?', 'n\n', 'republican'], ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', '?', 'n', 'n', 'n', 'n', 'n', 'n', '?\n', 'democrat'], ['n', 'y', 'n', 'y', 'y', 'y', '?', 'n', 'n', 'n', 'n', '?', 'y', 'y', 'n', 'n\n', 'republican'], ['n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', '?', 'y', 'n', 'n', 'y', 'n', 'y', 'y\n', 'democrat'], ['n', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y\n', 'democrat'], ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['y', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'y', '?', 'y', 'y', 'y', 'y\n', 'democrat'], ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y\n', 'republican'], ['n', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', '?\n', 'democrat'], ['?', '?', 'y', 'n', 'n', 'n', 'y', 'y', 'y', '?', '?', 'n', 'n', 'n', '?', '?\n', 'democrat'], ['n', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', '?\n', 'democrat'], ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y\n', 'democrat'], ['n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y\n', 'republican'], ['y', 'n', 'y', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'y\n', 'democrat'], ['y', 'n', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y', 'n', 'y', '?', 'y\n', 'republican'], ['y', 'y', 'y', 'n', 'n', '?', 'y', 'y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y\n', 'democrat'], ['y', 'n', 'y', 'n', '?', 'n', 'y', 'y', 'y', 'y', 'n', 'y', 'n', '?', 'y', 'y\n', 'democrat'], ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n\n', 'republican'], ['y', '?', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', '?', 'y', '?', '?\n', 'republican'], ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', '?\n', 'democrat'],  ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 8
#       4 votes_dataset = dataset('/home/carlos/Machine_Learning_Practice/datasets/house-votes-84.data', 'first')
#       5 print(f"voter Dataset w/o imputation: {votes_dataset.partitions}")
# ----> 8 cancer_dataset.imputate(False)
#       9 print(f"Cancer Dataset w/ imputation: {cancer_dataset.partitions}")
#      10 votes_dataset.imputate(True)
#
# Cell In[22], line 64, in dataset.imputate(self, voter_bool)
#      61 for example in range(self.example_count):
#      62     for attribute in range(self.attribute_count):
#      63         # if this statement is entered that means there is a missing piece of attribute data, so imputation needs to occur at this location
# ---> 64         if (self.partitions[partition][example][attribute] == '?'):
#      65             # This will be the imputation method using 'y' or 'n'
#      66             if (voter_bool == True):
#      67                 self.partitions[partition][example][attribute] = random.choice(voter_options)
#
# IndexError: list index out of range

# %%
# .discretize() testing

# %%
# .add_noise() testing
